# %%
# importando bibliotecas

# numericas
import numpy as np

# manipulacao de dados
import pandas as pd

# graficas
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# utilidades
# from google.colab import drive

import warnings
warnings.filterwarnings('ignore')

from collections import Counter

# %%
# Carregando Dados
df = pd.read_csv('https://raw.githubusercontent.com/ImagineDogs/TranstornosMentais/main/dados/df_cid10.csv')

# %%
# Filtra as colunas de datas no DataFrame e as converte para o formato de data
datas = df.filter(regex=('data')).columns
for data in datas:
  df[data] = pd.to_datetime(df[data]
                              .astype(str)
                              .apply(lambda x: x.split()[0]),
                              format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8755 entries, 0 to 8754
# Data columns (total 84 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   data_internacao_real              8755 non-null   datetime64[ns]
#  1   data_cadastro                     8653 non-null   datetime64[ns]
#  2   sexo                              8755 non-null   object
#  3   data_nascimento                   8422 non-null   datetime64[ns]
#  4   uf                                8755 non-null   object
#  5   municipio                         8755 non-null   object
#  6   profissao_ocupacao                8754 non-null   object
#  7   cod_paciente                      8755 non-null   int64
#  8   unidade_cadastro                  8755 non-null   int64
#  9   estado_civil                      8755 non-null   object
#  10  etnia                             8755 non-null   object
#  11  arranjo_domiciliar                8755 non-null   object
#  12  cod_regulacao                     8755 non-null   int64
#  13  cod_unidade_origem                8548 non-null   float64
#  14  data_solicitacao                  8755 non-null   datetime64[ns]
#  15  tipo_regulacao                    8755 non-null   object
#  16  cid10_diagnostico                 8318 non-null   object
#  17  cid10_seg_diagnostico             3584 non-null   object
#  18  data_lista_reg                    2074 non-null   datetime64[ns]
#  19  data_vaga_reg                     2207 non-null   datetime64[ns]
#  20  data_admissao_reg                 2212 non-null   datetime64[ns]
#  21  data_lista_hospital               7360 non-null   datetime64[ns]
#  22  data_vaga_hospital                7166 non-null   datetime64[ns]
#  23  data_internacao                   7330 non-null   datetime64[ns]
#  24  data_cancel_solicitacao           392 non-null    datetime64[ns]
#  25  data_transferencia                1500 non-null   datetime64[ns]
#  26  traumatismo                       8755 non-null   object
#  27  prob_respiratorios                8755 non-null   object
#  28  avc                               8755 non-null   object
#  29  convulsao                         8755 non-null   object
#  30  has                               8755 non-null   object
#  31  gravidez                          8755 non-null   object
#  32  diabetes                          8755 non-null   object
#  33  doenca_infecto                    8755 non-null   object
#  34  tipo_internacao_de                8755 non-null   object
#  35  data_expiracao                    4575 non-null   datetime64[ns]
#  36  cod_transf_alta                   1 non-null      float64
#  37  status_internacao                 8754 non-null   float64
#  38  data_alta                         8740 non-null   datetime64[ns]
#  39  cid10_diagnostico_alta            8739 non-null   object
#  40  cid10_seg_diagnostico_alta        3087 non-null   object
#  41  tipo_alta                         8755 non-null   object
#  42  tipo_internacao                   8755 non-null   object
#  43  nome_unidade_solicitacao          8755 non-null   object
#  44  nome_unidade_destino              8755 non-null   object
#  45  via_internacao                    8755 non-null   object
#  46  tempo_espera_internacao           8525 non-null   float64
#  47  tempo_espera_aceite               8557 non-null   float64
#  48  idade                             7328 non-null   float64
#  49  grupo_diagnostico_alta            8755 non-null   object
#  50  faixa_etaria                      7322 non-null   object
#  51  tempo_internacao                  8717 non-null   float64
#  52  event                             8740 non-null   float64
#  53  qtd_internacoes                   8755 non-null   int64
#  54  total_repeat_cod                  8755 non-null   float64
#  55  total_repeat                      8755 non-null   float64
#  56  sum_los_hour                      8631 non-null   float64
#  57  sum_outside_hour                  8755 non-null   float64
#  58  cumsum                            8694 non-null   float64
#  59  cumsum.1                          8697 non-null   float64
#  60  cumsum.1(start)                   8713 non-null   float64
#  61  start                             8736 non-null   float64
#  62  stop                              8694 non-null   float64
#  63  tempo_internado                   8740 non-null   float64
#  64  descricao_diagnostico             8318 non-null   object
#  65  descricao_seg_diagnostico         3579 non-null   object
#  66  descricao_diagnostico_alta        8726 non-null   object
#  67  descricao_seg_diagnostico_alta    3079 non-null   object
#  68  cid10_familia                     8318 non-null   object
#  69  cid10_descricao_familia           8318 non-null   object
#  70  cid10_seg_familia                 3584 non-null   object
#  71  cid10_seg_descricao_familia       3584 non-null   object
#  72  cid10_familia_alta                8730 non-null   object
#  73  cid10_descricao_familia_alta      8730 non-null   object
#  74  cid10_seg_familia_alta            3083 non-null   object
#  75  cid10_seg_descricao_familia_alta  3083 non-null   object
#  76  cid10_faixa                       8218 non-null   object
#  77  cid10_descricao_faixa             8218 non-null   object
#  78  cid10_seg_faixa                   3393 non-null   object
#  79  cid10_seg_descricao_faixa         3393 non-null   object
#  80  cid10_faixa_alta                  8645 non-null   object
#  81  cid10_descricao_faixa_alta        8645 non-null   object
#  82  cid10_seg_faixa_alta              2954 non-null   object
#  83  cid10_seg_descricao_faixa_alta    2954 non-null   object
# dtypes: datetime64[ns](14), float64(18), int64(4), object(48)
# memory usage: 5.6+ MB

# %%
pacientes_repetidos = list((df['cod_paciente'].value_counts()>1).loc[lambda x : x == True].index)

# %%
print(pacientes_repetidos)
# Out:
# [1068, 230, 1426, 1157, 108, 1466, 242, 1389, 81, 1501, 1224, 1331, 103, 70, 6727, 1590, 3247, 188, 3883, 6574, 1755, 1412, 1352, 1672, 1266, 1461, 1613, 677, 4972, 1793, 1623, 2710, 1577, 1555, 298, 5240, 4619, 2441, 1875, 2325, 1004, 1146, 889, 126, 640, 4526, 117, 3046, 4710, 40, 1640, 1264, 362, 224, 4693, 3656, 245, 5227, 2302, 815, 811, 3620, 621, 3174, 296, 6603, 4900, 394, 908, 4976, 152, 2682, 5093, 5868, 2534, 5271, 3704, 1629, 1608, 1556, 1532, 1319, 3860, 3976, 1991, 1226, 5843, 915, 2123, 916, 1405, 3144, 3324, 402, 1612, 4890, 1601, 4783, 324, 1306, 1300, 1429, 1420, 256, 231, 1510, 243, 1480, 1446, 3272, 1522, 1748, 1699, 1202, 6678, 4660, 2203, 928, 2073, 6987, 1956, 784, 2365, 2386, 2396, 1884, 700, 693, 2454, 2463, 1843, 1826, 6914, 1176, 5773, 1194, 1196, 2679, 2163, 213, 3932, 1386, 86, 4542, 97, 3501, 120, 3539, 172, 3566, 2540, 9110, 74, 2631, 2610, 6097, 2513, 1624, 5075, 3556, 2587, 6082, 3553, 2586, 2579, 1643, 1652, 591, 6397, 162, 448, 3063, 4572, 4831, 361, 1303, 2944, 1548, 1301, 168, 7223, 2817, 1284, 4931, 2757, 424, 1278, 2726, 6344, 4958, 670, 3587, 9188, 1865, 1801, 6316, 5260, 2160, 2157, 3747, 921, 1864, 1089, 5411, 4756, 1873, 6937, 6939, 1898, 6944, 1907, 1005, 1922, 1944, 1794, 1779
3161, 3168, 3179, 3188, 3480, 8441, 7336, 8436, 3228, 3238, 4548, 7151, 5068, 4506, 7443, 7019, 2121, 7909, 3678, 4502, 5269, 7442, 2143, 2158, 2211, 9389, 7031, 5256, 2176, 2177, 2186, 2189, 2201, 2202, 2097, 2083, 2077, 7450, 1966, 3725, 1985, 1987, 1989, 4485, 2005, 5335, 2016, 2020, 9470, 5323, 2042, 5314, 2057, 2058, 4486, 5307 ...

# %%
# Divide o DataFrame de internações em pacientes repetidos e pacientes únicos
df_repetidos = df[df['cod_paciente'].isin(pacientes_repetidos)]
df_unicos = df[~df['cod_paciente'].isin(pacientes_repetidos)]

# Conta o número de pacientes únicos e repetidos
num_pacientes_repetidos = len(df_repetidos['cod_paciente'].unique())
num_pacientes_unicos = len(df_unicos['cod_paciente'].unique())

# Imprime o número de pacientes únicos e repetidos
print(f"Número de pacientes repetidos: {num_pacientes_repetidos}")
print(f"Número de pacientes únicos: {num_pacientes_unicos}")
# Out:
# Número de pacientes repetidos: 1790
# Número de pacientes únicos: 3183

# %%
# ~ Observando as internações de um paciente repetido qualquer ~

# Seleciona as colunas de interesse para o paciente 1068
colunas_selecionadas = [
    'idade',
    'data_internacao_real',
    'data_alta',
    'qtd_internacoes',
    'tempo_internado',
    'tempo_internacao',
    'descricao_diagnostico',
    'descricao_seg_diagnostico',
    'descricao_diagnostico_alta',
    'descricao_seg_diagnostico_alta',
    'cid10_faixa',
    'cid10_seg_faixa',
    'cid10_faixa_alta',
    'cid10_seg_faixa_alta'
]

# Filtra o DataFrame para os dados do paciente com código 1068
dados_paciente_1068 = df[df['cod_paciente'] == 1068][colunas_selecionadas]

# Exibe os dados do paciente 1068
dados_paciente_1068
# Out:
#       idade data_internacao_real  data_alta  qtd_internacoes  tempo_internado  \
# 1297   31.0           2012-10-15 2012-10-19               20              4.0
# 1298   31.0           2012-11-26 2013-01-11               20             46.0
# 1299   32.0           2013-02-05 2013-05-20               20            104.0
# 1300   32.0           2013-08-20 2013-08-28               20              8.0
# 1301   32.0           2013-10-03 2013-10-14               20             11.0
# 1302   32.0           2013-11-27 2013-12-03               20              6.0
# 1303   33.0           2014-02-01 2014-02-03               20              2.0
# 1304   33.0           2014-03-28 2014-04-09               20             12.0
# 1305   34.0           2015-11-07 2015-11-11               20              4.0
# 1306   34.0           2015-11-11 2015-11-26               20             15.0
# 1307   34.0           2015-11-30 2015-12-31               20             31.0
# 1308   35.0           2016-01-07 2016-03-15               20             68.0
# 1309   35.0           2016-08-16 2016-08-16               20              0.0
# 1310   35.0           2016-08-19 2016-08-26               20              7.0
# 1311   35.0           2016-09-17 2016-10-18               20             31.0
# 1312   35.0           2016-10-18 2016-10-31               20             13.0
# 1313   35.0           2016-12-21 2017-01-05               20             15.0
# 1314   36.0           2017-03-07 2017-03-09               20              2.0
# 1315   36.0           2017-03-10 2017-03-11               20              1.0
# 1316   36.0           2017-03-15 2017-03-17               20              2.0
#
#       tempo_internacao                              descricao_diagnostico  \
# 1297         95.850000                              Episódios depressivos
# 1298       1096.883333  Transtornos mentais e comportamentais devidos ...
# 1299       2493.283333  Transtornos mentais e comportamentais devidos ...
# 1311                                                NaN     F60-F69
# 1312                                                NaN     F60-F69
# 1313                                                NaN     F10-F19
# 1314           Transtornos específicos da personalidade     F10-F19
# 1315                                                NaN     F60-F69
# 1316                                                NaN     F60-F69
#
#      cid10_seg_faixa cid10_faixa_alta cid10_seg_faixa_alta
# 1297         F10-F19          F10-F19                  NaN
# 1298         F30-F39          F10-F19              F30-F39
# 1299         F60-F69          F10-F19                  NaN
# 1300         F10-F19          F10-F19                  NaN
# 1301         F10-F19          F10-F19                  NaN
# 1302         F20-F29          F10-F19                  NaN
# 1303             NaN          F10-F19              F60-F69
# 1304         F60-F69          F10-F19                  NaN
# 1305             NaN          F30-F39              F10-F19
# 1306         F10-F19          F30-F39              F10-F19
# 1307         F60-F69          F10-F19              F60-F69
# 1308         F10-F19          F10-F19              F60-F69
# 1309         F10-F19          F30-F39              F10-F19
# 1310         F10-F19          F10-F19                  NaN
# 1311             NaN          F30-F39                  NaN
# 1312             NaN          F10-F19                  NaN
# 1313             NaN          F10-F19                  NaN
# 1314             NaN          F10-F19              F60-F69
# 1315             NaN          F60-F69                  NaN
# 1316             NaN          F60-F69                  NaN

# %%
# Calcula informações das internações por 'cod_paciente'
df['data_primeira_internacao'] = df.groupby('cod_paciente')['data_internacao_real'].transform('min')
df['data_ultima_internacao'] = df.groupby('cod_paciente')['data_internacao_real'].transform('max')
df['duracao_total_internacoes'] = df.groupby('cod_paciente')['tempo_internado'].transform('sum')

# Cria um DataFrame de PACIENTES com apenas 1 registro para cada paciente
# Incorpora tanto os pacientes repetidos quanto os paciente únicos
pacientes_df = df.drop_duplicates(subset='cod_paciente').reset_index(drop=True)

# Seleciona as colunas relevantes
pacientes_df = pacientes_df[['cod_paciente', 'sexo', 'data_nascimento', 'uf', 'municipio', 'profissao_ocupacao', 'estado_civil', 'etnia', 'arranjo_domiciliar', 'qtd_internacoes', 'data_primeira_internacao',
'data_ultima_internacao',
'duracao_total_internacoes']]

# Exibe as primeiras linhas do DataFrame de pacientes
pacientes_df.head()
# Out:
#    cod_paciente sexo data_nascimento  uf                   municipio  \
# 0            39    F      1957-07-30  SP              RIBEIRAO PRETO
# 1            40    F      1971-02-10  SP              RIBEIRAO PRETO
# 2            41    F      1990-11-29  SP       SANTA ROSA DE VITERBO
# 3            42    F      1982-02-05  SP  SANTA RITA DO PASSA QUATRO
# 4            43    F      1970-01-14  SP                      FRANCA
#
#   profissao_ocupacao estado_civil   etnia arranjo_domiciliar  qtd_internacoes  \
# 0       DONA DE CASA     SOLTEIRO  BRANCO      NAO INFORMADO                1
# 1       DESEMPREGADA     SOLTEIRO  BRANCO      NAO INFORMADO                8
# 2      NAO INFORMADO       CASADO  BRANCO            SOZINHO                1
# 3      NAO INFORMADO     SOLTEIRO  BRANCO      NAO INFORMADO                1
# 4      NAO INFORMADO     SOLTEIRO  BRANCO      NAO INFORMADO                4
#
#   data_primeira_internacao data_ultima_internacao  duracao_total_internacoes
# 0               2012-07-12             2012-07-12                       81.0
# 1               2012-06-25             2017-12-20                      678.0
# 2               2012-06-26             2012-06-26                       48.0
# 3               2012-07-23             2012-07-23                       18.0
# 4               2012-07-17             2016-10-07                      559.0
